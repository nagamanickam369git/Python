# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
print(input("Enter your institute name? : "))
# Out:
# Enter your institute name? :  HOPE AI
# HOPE AI

# %%
print(input("Enter your name: "))
print(input("Enter your age: "))
print(input("Enter your school name: "))
print(input("Enter your degree: "))
# Out:
# Enter your name:  Manickam
# Manickam
# Enter your age:  15
# 15
# Enter your school name:  Guru scholl
# Guru scholl
# Enter your degree:  B.E CSE
# B.E CSE

# %%
a = 43
b = 34
print("a=",a)
print("b=",b)
print("add =",a+b)
# Out:
# a= 43
# b= 34
# add = 77

# %%
a = 43
b = 34
print("a=",a)
print("b=",b)
print("Sub =",a-b)
# Out:
# a= 43
# b= 34
# Sub = 9

# %%
a = 63
b = 97
print("a=",a)
print("b=",b)
print("Mul =",a*b)
# Out:
# a= 63
# b= 97
# Mul = 6111

# %%
a = 76
b = 31
print("a=",a)
print("b=",b)
print("float Div =",a/b)
# Out:
# a= 76
# b= 31
# float Div = 2.4516129032258065

# %%
a = 76
b = 31
print("a=",a)
print("b=",b)
print("Floor Div =",int(a/b))
# Out:
# a= 76
# b= 31
# Floor Div = 2

# %%
a = 76
b = 31
print("a=",a)
print("b=",b)
print("Modulo =",a%b)
# Out:
# a= 76
# b= 31
# Modulo = 14

# %%
a = 4
b = 4
print("a=",a)
print("b=",b)
print("Modulo =",a**b)
# Out:
# a= 4
# b= 4
# Modulo = 256
