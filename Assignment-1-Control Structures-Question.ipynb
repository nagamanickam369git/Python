# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10;Num2=30;
print("Num1= ",Num1)
print("Num2= ",Num2)
print("Add= ",Num2+Num1)
# Out:
# Num1=  10
# Num2=  30
# Add=  40

# %% [markdown]
# BMI < 18.5         => Underweight
# BMI = 18.5-24.9    => Normal weight
# BMI = 25-29.9      => Overweight
# BMI > 30.0         => Obesity

# %%
BMI = float(input("Enter the BMI Index: "))
if(BMI <= 18.5):
    print("Your are in Underweight")
elif(BMI > 18.5 and BMI <= 24.9):  
    print("Your are in Normal weight")
elif(BMI > 24.9 and BMI <= 29.9):  
    print("Your are in Overweight")
else:  
    print("Your are in Obesity")
# Out:
# Enter the BMI Index:  18.6
# Your are in Normal weight
