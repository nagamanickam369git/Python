# %%
from classAssignment import multipleFunction

# %%
list = ["Machine Learning","Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
multipleFunction.Subfields(list)
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multipleFunction.OddEven()
# Out:
# Enter a number: 441
# 441 is Odd number
# (441, 'is Odd number')

# %%
multipleFunction.Elegible()
# Out:
# Your Gender: male
# Your Age: 25
# Eligible
# 'Eligible'

# %%
multipleFunction.percentage(95,82,97,90,75)
# Out:
# Subject1= 95
# Subject2= 82
# Subject3= 97
# Subject4= 90
# Subject5= 75
# Total: 439
# Percentage: 87.8
# (439, 87.8)

# %%
multipleFunction.triangle()
# Out:
# Height: 45
# Breadth: 45
# Area formula: (Height*Breadth) / 2
# Area of Traingle: 1012.5
# Height1: 45
# Height2: 45
# Breadth: 45
# Perimeter formula: Height1 + Height2 + Breadth
# Perimeter of Traingle: 135
# (1012.5, 135)
